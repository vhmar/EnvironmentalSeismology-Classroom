# %%
using SAC

# %%
data=SAC.read("Patricia100.sac")
# Out:
# INFO: Data are little-endian; byteswapping
# SAC.SACtr:
#     delta: 0.01
#    depmin: -1.8321003e8
#    depmax: 1.4286283e8
#     scale: 1.0
#         b: 0.0
#         e: 25199.99
#    depmen: -1.8947932e6
#    nzyear: 2015
#    nzjday: 296
#    nzhour: 21
#     nzmin: 0
#     nzsec: 0
#    nzmsec: 0
#     nvhdr: 6
#      npts: 2520000
#    iftype: 1
#    iztype: 9
#     leven: true
#    lpspol: true
#    lovrok: true
#    lcalda: false
#  unused18: true
#     kstnm: SHK2
#     kevnm: -12345  -12345
#    kcmpnm: HHZ

# %%
p100=data.t;

# %%
using PyPlot

# %%
fig=figure(figsize=(12,6))
plot(data.t,"-g")
title("Lahar Patricia_100")
xlabel("Tiempo[s]")
ylabel("Amplitud[]")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000002C270978>)
# PyObject <matplotlib.text.Text object at 0x000000002C4C7EB8>

# %%
length(p100)
# Out:
# 2520000

# %%
#Envolvente
env= p100.*p100;

# %%
fig= figure(figsize=(12,5))
plot(env,"y")
title("Envolvente(?)")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x0000000036B32C88>)
# PyObject <matplotlib.text.Text object at 0x000000004EC16278>

# %%
function Hil(x::Float32)
    y=zeros(length(x))
       for i=1:length(x)
        y[i]= x[i].*x[i]
    end
    return y
end
# Out:
# Hil (generic function with 2 methods)

# %%
methods(Hil)
# Out:
# # 2 methods for generic function "Hil":
# Hil(x::Float32) in Main at In[20]:2
# Hil(x) in Main at In[13]:2

# %%
#Fou=abs.(fft(env,1))
# Out:
# UndefVarError: hilbert not defined
#
# Stacktrace:
#  [1] include_string(::String, ::String) at .\loading.jl:515

# %%
plot(y)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000002ACC6710>)
# OMP: Warning #72: KMP_AFFINITY: affinity only supported for Intel(R) processors.
# OMP: Warning #71: KMP_AFFINITY: affinity not supported, using "none".
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x000000002ADD18D0>

# %%
using DSP

# %%
hilbert
# Out:
# hilbert (generic function with 3 methods)
