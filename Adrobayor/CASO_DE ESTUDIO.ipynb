# %% [markdown]
# # señal

# %%
from obspy import read

# %%
import numpy as np

# %%
from obspy import UTCDateTime, Stream

# %%
from scipy import signal

# %%
from numpy.fft import fft
from numpy import array

# %%
st = read("Package_AguilleDru_2377562_SED.mseed")

# %%
st2 = st.select(id="CH.EMV..HHZ")
st3 = st.select(id="CH.EMV..HHN")
st4 = st.select(id="CH.EMV..HHE")
st5 = st.select(id="CH.FUSIO..HHZ")
st6 = st.select(id="CH.FUSIO..HHN")
st7 = st.select(id="CH.FUSIO..HHE")

# %%
print(st2, st3, st4)
# Out:
# 1 Trace(s) in Stream:
# CH.EMV..HHZ | 2005-06-30T01:19:54.988333Z - 2005-06-30T01:30:00.430000Z | 120.0 Hz, 72654 samples 1 Trace(s) in Stream:
# CH.EMV..HHN | 2005-06-30T01:19:59.230000Z - 2005-06-30T01:30:02.388333Z | 120.0 Hz, 72380 samples 1 Trace(s) in Stream:
# CH.EMV..HHE | 2005-06-30T01:19:57.513333Z - 2005-06-30T01:30:00.180000Z | 120.0 Hz, 72321 samples

# %%
st2.plot(color="red")
st3.plot(color="blue")
st4.plot(color="orange")
st5.plot(color="green")
st6.plot()

# %%
len(st2)
len(st3)
len(st4)
len(st5)
len(st6)
# Out:
# 1

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import obspy

# %%
import obspy.signal

# %%
data = st2[0].data
npts = st2[0].stats.npts
samprate = st[0].stats.sampling_rate

# %%
st2_filt = st2.copy()
st2_filt.filter("bandpass", freqmin=1, freqmax=30, corners=2, zerophase=True)
# Out:
# 1 Trace(s) in Stream:
# CH.EMV..HHZ | 2005-06-30T01:19:54.988333Z - 2005-06-30T01:30:00.430000Z | 120.0 Hz, 72654 samples

# %%
data_envelope = obspy.signal.filter.envelope(st2[0].data)

# %%
plt.figure(figsize=(8,3))
plt.plot(data_envelope)

# %%
x = st2[0].data

# %%
x2 = x-np.mean(x)

# %%
plt.figure(figsize=(8,4))
plt.plot(x2)

# %%
x2 = signal.detrend(x2)

# %%
plt.plot(x2)

# %%
np.array([x2])
# Out:
# array([[ 36.93921268,  38.93916969,  42.9391267 , ...,  89.8160141 ,
#          92.81597111,  87.81592812]])

# %%
a = np.array([x2])
